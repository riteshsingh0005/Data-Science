# %%
import pandas as pd

# %% [markdown]
# -creating dataset
#    -dictionary of items
#    -list of dictionary
#    -import csv,xlsx or json files
#
# -get basic insights
# -data selection
#     -row wise selection
#     -column wise selection
#
# -data cleaning and manipulation

# %%
movies={
    'title':['pk','ddlj','soty'],
    'year':[2019,1997,2017],
    'rating':[8.8,9.2,8.9],
    'genre':['comedy','romantic','comedy']
}
df=pd.DataFrame(movies)
df
# Out:
#   title  year  rating     genre
# 0    pk  2019     8.8    comedy
# 1  ddlj  1997     9.2  romantic
# 2  soty  2017     8.9    comedy

# %%
movies =[
    {'title':'pk','year':2019,'rating':8.8,'genre':'comedy'},
    {'title':'ddlj','year':1997,'rating':9.2,'genre':'romantic'},
    {'title':'soty','year':2017,'rating':8.9,'genre':'comedy'},
]
df=pd.DataFrame(movies)
df
# Out:
#   title  year  rating     genre
# 0    pk  2019     8.8    comedy
# 1  ddlj  1997     9.2  romantic
# 2  soty  2017     8.9    comedy

# %%
df=pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head() #display the first five rows of the dataFrame by default
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail() #displays last five rows of data frame by default
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.head(10) #display according to which you write
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.sample(5) #randomly gives you five rows
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 18746  1830300090  20150401T000000  670000.0         5       3.00
# 6571   3275760190  20140624T000000  600000.0         4       1.75
# 9257   3995700325  20140604T000000  275000.0         2       1.00
# 6169   2321300351  20140612T000000  575000.0         2       1.00
# 19070  1321400650  20140603T000000  250000.0         3       2.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 18746         2520     13001     2.0           0     1  ...      8
# 6571          1740      7700     1.0           0     0  ...      7
# 9257           770      8149     1.0           0     0  ...      6
# 6169          1510      4032     1.5           0     0  ...      8
# 19070         1765      7652     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 18746        2010            510      1973             0    98008  47.6385
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.info() #display info in concise form means basic information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe() #get summary statistics for numerical columns
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# -row wise selection
#     -iloc=index based selection
#     -loc=label based selection
# -column wise selection
#     -single column selection
#        -dictionary like selection
#        -object like selection
#
# -multiple column selection
#    -dictionary like selection

# %%
df.iloc[2] #select the third row by index
# Out:
# id                    5631500400
# date             20150225T000000
# price                   180000.0
# bedrooms                       2
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 2, dtype: object

# %%
df.iloc[-3] #select third row by last
# Out:
# id                    1523300141
# date             20140623T000000
# price                   402101.0
# bedrooms                       2
# bathrooms                   0.75
# sqft_living                 1020
# sqft_lot                    1350
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1020
# sqft_basement                  0
# yr_built                    2009
# yr_renovated                   0
# zipcode                    98144
# lat                      47.5944
# long                    -122.299
# sqft_living15               1020
# sqft_lot15                  2007
# Name: 21610, dtype: object

# %%
df.iloc[2:6] #select rows from index 2 to 5(exclusive of 6)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 2  5631500400  20150225T000000   180000.0         2        1.0          770
# 3  2487200875  20141209T000000   604000.0         4        3.0         1960
# 4  1954400510  20150218T000000   510000.0         3        2.0         1680
# 5  7237550310  20140512T000000  1225000.0         4        4.5         5420
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 2      1933             0    98028  47.7379 -122.233           2720
# ...

# %%
df.iloc[[3,5,9,11]] #select sepcific rows by index
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 3   2487200875  20141209T000000   604000.0         4        3.0         1960
# 5   7237550310  20140512T000000  1225000.0         4        4.5         5420
# 9   3793500160  20150312T000000   323000.0         3        2.5         1890
# 11  9212900260  20140527T000000   468000.0         2        1.0         1160
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3       5000     1.0           0     0  ...      7        1050            910
# 5     101930     1.0           0     0  ...     11        3890           1530
# 9       6560     2.0           0     0  ...      7        1890              0
# 11      6000     1.0           0     0  ...      7         860            300
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 3       1965             0    98136  47.5208 -122.393           1360
# ...

# %%
df.iloc[[0,2,4],[2,3]] #for getting particular rows and columns
# Out:
#       price  bedrooms
# 0  221900.0         3
# 2  180000.0         2
# 4  510000.0         3

# %%
df=df.set_index('id') #set 'id' column as the index of the DataFrame
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.loc[7129300520]
# Out:
# date             20141013T000000
# price                   221900.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 7129300520, dtype: object

# %%
df.loc[[291310100,6600060120]] #select specific
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 291310100   20150116T000000  400000.0         3        2.5         1600
# 6600060120  20150223T000000  400000.0         4        2.5         2310
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 291310100       2388     2.0           0     0          3      8        1600
# 6600060120      5813     2.0           0     0          3      8        2310
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 291310100               0      2004             0    98027  47.5345 -122.069
# 6600060120              0      2014             0    98146  47.5107 -122.362
#
#             sqft_living15  sqft_lot15
# id
# 291310100            1410        1287
# 6600060120           1830        7200

# %%
df['price'] #select a single column by name
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price #select a single column by name (alternative option)
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[['bedrooms','bathrooms']] #select multiple columns by name
# Out:
#             bedrooms  bathrooms
# id
# 7129300520         3       1.00
# 6414100192         3       2.25
# 5631500400         2       1.00
# 2487200875         4       3.00
# 1954400510         3       2.00
# ...              ...        ...
# 263000018          3       2.50
# 6600060120         4       2.50
# 1523300141         2       0.75
# 291310100          3       2.50
# 1523300157         2       0.75
#
# [21613 rows x 2 columns]

# %% [markdown]
# DATA MANIPULATION
# -to remove columns and rows
# -to rename columns
# -to delete missing values
# -to handle missing values
# -to change the datatype of a column
# -to count the categorical data

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop=['sqft_living15','sqft_lot15']
df= df.drop(columns=cols_to_drop) #drop specified columns
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
df=df.drop(labels=[7129300520])
df

# %%
rename = {
    'lat':'latitude',
    'long':'longitude'
}
df=df.rename(columns=rename) #rename columns using a dictionary
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'latitude',
#        'longitude'],
#       dtype='object')
